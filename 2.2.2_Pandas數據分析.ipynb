# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("grades.csv")

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()
# Out:
# <Axes: >

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins=15)
# Out:
# <Axes: >

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# np.float64(11.39)

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: '劉俊安'

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# np.float64(-0.3108989822179331)

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis = 1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df["總級分"] = df.sum(axis = 1)
#       2 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)  12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\_methods.py:51, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      49 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      50          initial=_NoValue, where=True):
# ---> 51     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df['加權'] = df.國文+df.英文+df.數學*2

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會  加權
# 0   劉俊安   9  10  15  10  13  49
# 1   胡玉華  10  10  10   8   9  40
# 2   黃淑婷  13  15   8  11  14  44
# 3   陳上紫  10  10   8   9  14  36
# 4   崔靜成  13  12  14  12  13  53
# ..  ...  ..  ..  ..  ..  ..  ..
# 95  蔡佳燕   9  10   9  13  14  37
# 96  吳筱婷   8  10  14  10  15  46
# 97  陳家銘  14   9  11   8  12  45
# 98  李明威  15   9   8   9  15  40
# 99  農揚勇   9  11  12  12  10  44
#
# [100 rows x 7 columns]

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by='總級分',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.sort_values(by='總級分',ascending=False).head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7211, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7205     indexer = lexsort_indexer(
#    7206         keys, orders=ascending, na_position=na_position, key=key
#    7207     )
#    7208 elif len(by):
#    7209     # len(by) == 1
# -> 7211     k = self._get_label_or_level_values(by[0], axis=axis)
#    7213     # need to rewrap column in Series to apply key function
#    7214     if key is not None:
#    7215         # error: Incompatible types in assignment (expression has type
#    7216         # "Series", variable has type "ndarray")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1914, in NDFrame._get_label_or_level_values(self, key, axis)
#    1912     values = self.axes[axis].get_level_values(key)._values
#    1913 else:
# -> 1914     raise KeyError(key)
#    1916 # Check for duplicates
#    1917 if values.ndim > 1:
#
# KeyError: '總級分'

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by = ['加權','總級分'],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df2 = df.sort_values(by = ['加權','總級分'],ascending=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7194, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7189     raise ValueError(
#    7190         f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7191         f" != length of by ({len(by)})"
#    7192     )
#    7193 if len(by) > 1:
# -> 7194     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7196     # need to rewrap columns in Series to apply key function
#    7197     if key is not None:
#    7198         # error: List comprehension has incompatible type List[Series];
#    7199         # expected List[ndarray]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1914, in NDFrame._get_label_or_level_values(self, key, axis)
#    1912     values = self.axes[axis].get_level_values(key)._values
#    1913 else:
# -> 1914     raise KeyError(key)
#    1916 # Check for duplicates
#    1917 if values.ndim > 1:
#
# KeyError: '總級分'

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1,101)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df2.index = range(1,101)
#       2 df2.head()
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學==15]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df2[df2.數學==15]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
result = df[(df["數學"] == 15) & (df["英文"] == 15)]

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2.drop("總級分",axis=1)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df2.drop("總級分",axis=1)
#       2 df2
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop("總級分",axis=1,inplace=True)
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df2.drop("總級分",axis=1,inplace=True)
#       2 df2
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.drop(5).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df2.drop(5).head()
#
# NameError: name 'df2' is not defined

# %%
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2[df2.姓名=="李士賢"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df2[df2.姓名=="李士賢"]
#
# NameError: name 'df2' is not defined

# %%
df2.drop(df2[df2.姓名=="李士賢"].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df2.drop(df2[df2.姓名=="李士賢"].index)
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %%
conda install pandas-datareader
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\eemrt\anaconda3
#
#   added / updated specs:
#     - pandas-datareader
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       haa95532_0         125 KB
#     certifi-2026.01.04         |  py313haa95532_0         148 KB
#     conda-26.1.1               |  py313haa95532_0         1.2 MB
#     openssl-3.5.5              |       hbb43b14_0         8.9 MB
#     pandas-datareader-0.10.0   |     pyhd3eb1b0_0          71 KB
#     ------------------------------------------------------------
#                                            Total:        10.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas-datareader  pkgs/main/noarch::pandas-datareader-0.10.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.11.4-haa95532_0 --> 2025.12.2-haa95532_0
#   certifi                        2025.11.12-py313haa95532_0 --> 2026.01.04-py313haa95532_0
#   conda                             25.11.1-py313haa95532_0 --> 26.1.1-py313haa95532_0
#   openssl                                 3.0.18-h543e019_0 --> 3.5.5-hbb43b14_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.5        | 8.9 MB    |            |   0%
#
# conda-26.1.1         | 1.2 MB    |            |   0%
#
#
# certifi-2026.01.04   | 148 KB    |            |   0%
#
#
#
# ca-certificates-2025 | 125 KB    |            |   0%
#
#
#
#
# pandas-datareader-0. | 71 KB     |            |   0%
#
#
#
#
# pandas-datareader-0. | 71 KB     | ##2        |  22%
#
#
#
# ca-certificates-2025 | 125 KB    | #2         |  13%
#
#
#
#
# pandas-datareader-0. | 71 KB     | ########## | 100%
#
#
#
# ca-certificates-2025 | 125 KB    | ########## | 100%
#
#
# certifi-2026.01.04   | 148 KB    | #          |  11%
# openssl-3.5.5        | 8.9 MB    |            |   0%
#
#
# certifi-2026.01.04   | 148 KB    | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | 2          |   2%
#
# conda-26.1.1         | 1.2 MB    | 1          |   1%
# openssl-3.5.5        | 8.9 MB    | 5          |   6%
#
# conda-26.1.1         | 1.2 MB    | 8          |   9%
# openssl-3.5.5        | 8.9 MB    | 8          |   9%
#
# conda-26.1.1         | 1.2 MB    | #6         |  17%
# openssl-3.5.5        | 8.9 MB    | #1         |  12%
#
# conda-26.1.1         | 1.2 MB    | ##9        |  30%
# openssl-3.5.5        | 8.9 MB    | #4         |  14%
#
#
#
# ca-certificates-2025 | 125 KB    | ########## | 100%
#
#
#
# ca-certificates-2025 | 125 KB    | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | #6         |  17%
#
# conda-26.1.1         | 1.2 MB    | ###8       |  39%
#
#
# certifi-2026.01.04   | 148 KB    | ########## | 100%
#
#
# certifi-2026.01.04   | 148 KB    | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | #9         |  19%
#
# conda-26.1.1         | 1.2 MB    | ####4      |  45%
# openssl-3.5.5        | 8.9 MB    | ##1        |  21%
# openssl-3.5.5        | 8.9 MB    | ##3        |  23%
#
# conda-26.1.1         | 1.2 MB    | #####1     |  51%
# openssl-3.5.5        | 8.9 MB    | ##4        |  25%
#
# conda-26.1.1         | 1.2 MB    | #####6     |  57%
# openssl-3.5.5        | 8.9 MB    | ##6        |  27%
#
# conda-26.1.1         | 1.2 MB    | ######6    |  67%
# openssl-3.5.5        | 8.9 MB    | ##8        |  29%
#
# conda-26.1.1         | 1.2 MB    | #######3   |  73%
# openssl-3.5.5        | 8.9 MB    | ###1       |  32%
#
# conda-26.1.1         | 1.2 MB    | ########   |  81%
# openssl-3.5.5        | 8.9 MB    | ###4       |  34%
# openssl-3.5.5        | 8.9 MB    | ###6       |  37%
#
# conda-26.1.1         | 1.2 MB    | ########9  |  90%
#
#
#
#
# pandas-datareader-0. | 71 KB     | ########## | 100%
#
#
#
#
# pandas-datareader-0. | 71 KB     | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | ###8       |  39%
#
# conda-26.1.1         | 1.2 MB    | #########7 |  98%
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | ####1      |  41%
# openssl-3.5.5        | 8.9 MB    | ####4      |  45%
# openssl-3.5.5        | 8.9 MB    | ####7      |  48%
# openssl-3.5.5        | 8.9 MB    | #####      |  50%
# openssl-3.5.5        | 8.9 MB    | #####3     |  53%
# openssl-3.5.5        | 8.9 MB    | #####6     |  56%
# openssl-3.5.5        | 8.9 MB    | #####9     |  59%
# openssl-3.5.5        | 8.9 MB    | ######3    |  63%
# openssl-3.5.5        | 8.9 MB    | ######6    |  67%
# openssl-3.5.5        | 8.9 MB    | #######    |  70%
# openssl-3.5.5        | 8.9 MB    | #######4   |  74%
# openssl-3.5.5        | 8.9 MB    | #######8   |  78%
# openssl-3.5.5        | 8.9 MB    | ########2  |  82%
# openssl-3.5.5        | 8.9 MB    | ########6  |  86%
# openssl-3.5.5        | 8.9 MB    | #########  |  90%
# openssl-3.5.5        | 8.9 MB    | #########4 |  94%
# openssl-3.5.5        | 8.9 MB    | #########7 |  98%
# openssl-3.5.5        | 8.9 MB    | ########## | 100%
# openssl-3.5.5        | 8.9 MB    | ########## | 100%
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pd.read_csv('aapl.csv', index_col="Date")

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
# df = pd.read_csv('data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-10-03  112.709999  113.050003  112.279999  112.519997  110.173546
# 2016-10-04  113.059998  114.309998  112.629997  113.000000  110.643539
# 2016-10-05  113.400002  113.660004  112.690002  113.050003  110.692505
# 2016-10-06  113.699997  114.339996  113.129997  113.889999  111.514984
# 2016-10-07  114.309998  114.559998  113.510002  114.059998  111.681435
#
#               Volume
# Date
# 2016-10-03  21701800
# 2016-10-04  29736800
# 2016-10-05  21453100
# 2016-10-06  28779300
# 2016-10-07  24358400

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-10-03  112.709999  113.050003  112.279999  112.519997  110.173546
# 2016-10-04  113.059998  114.309998  112.629997  113.000000  110.643539
# 2016-10-05  113.400002  113.660004  112.690002  113.050003  110.692505
# 2016-10-06  113.699997  114.339996  113.129997  113.889999  111.514984
# 2016-10-07  114.309998  114.559998  113.510002  114.059998  111.681435
# ...                ...         ...         ...         ...         ...
# 2017-12-04  172.479996  172.619995  169.630005  169.800003  169.800003
# 2017-12-05  169.059998  171.520004  168.399994  169.639999  169.639999
# 2017-12-06  167.500000  170.199997  166.460007  169.009995  169.009995
# 2017-12-07  169.029999  170.440002  168.910004  169.320007  169.320007
# 2017-12-08  170.490005  171.000000  168.820007  169.369995  169.369995
#
#               Volume
# Date
# 2016-10-03  21701800
# 2016-10-04  29736800
# 2016-10-05  21453100
# 2016-10-06  28779300
# 2016-10-07  24358400
# ...              ...
# 2017-12-04  32542400
# 2017-12-05  27350200
# 2017-12-06  28560000
# 2017-12-07  25673300
# 2017-12-08  23173700
#
# [300 rows x 6 columns]

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.Close.rolling(20).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values

len(close)
# Out:
# 300

# %%
x = close[:-1]
len(x)
# Out:
# 299

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
import numpy as np
mydata
# Out:
# array([[ 1.16319253,  0.95179285,  0.78025951],
#        [-0.6721919 ,  0.88930103, -0.03260062],
#        [ 0.12647638,  0.24017215, -1.33613433],
#        [ 0.12213747, -1.02117915,  1.69019793]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  1.163193  0.951793  0.780260
# 1 -0.672192  0.889301 -0.032601
# 2  0.126476  0.240172 -1.336134
# 3  0.122137 -1.021179  1.690198

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0 -1.504374 -0.265171 -0.165342
# 1  0.102949  1.108726 -0.165392
# 2 -0.509931 -0.443772 -0.741462

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4
# Out:
#           A         B         C
# 0  1.163193  0.951793  0.780260
# 1 -0.672192  0.889301 -0.032601
# 2  0.126476  0.240172 -1.336134
# 3  0.122137 -1.021179  1.690198
# 0 -1.504374 -0.265171 -0.165342
# 1  0.102949  1.108726 -0.165392
# 2 -0.509931 -0.443772 -0.741462

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(7)

# %%
df4
# Out:
#           A         B         C
# 0  1.163193  0.951793  0.780260
# 1 -0.672192  0.889301 -0.032601
# 2  0.126476  0.240172 -1.336134
# 3  0.122137 -1.021179  1.690198
# 4 -1.504374 -0.265171 -0.165342
# 5  0.102949  1.108726 -0.165392
# 6 -0.509931 -0.443772 -0.741462

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2,df3],axis=1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0  1.163193  0.951793  0.780260 -1.504374 -0.265171 -0.165342
# 1 -0.672192  0.889301 -0.032601  0.102949  1.108726 -0.165392
# 2  0.126476  0.240172 -1.336134 -0.509931 -0.443772 -0.741462
# 3  0.122137 -1.021179  1.690198       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('names.csv',names=['姓名'])

# %%
df_names.head()
# Out:
#     姓名
# 0  羅雅慧
# 1  王紹尹
# 2  黃季坤
# 3  許正書
# 4  張鈞蓮

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0   13   7   9   7  12
# 1    8   6  11   8   9
# 2   11  13   7  11  15
# 3   14  12  10  10   6
# 4   13  15  15   6  15
# ..  ..  ..  ..  ..  ..
# 95   9  11  10   8  15
# 96  12   6   8  14  15
# 97  15  15  13  13  13
# 98  15  15  10  15  14
# 99   6  12  15   8  10
#
# [100 rows x 5 columns]

# %%
df_score = pd.concat([df_names,df_grades],axis=1)

# %%
df_score
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧  13   7   9   7  12
# 1   王紹尹   8   6  11   8   9
# 2   黃季坤  11  13   7  11  15
# 3   許正書  14  12  10  10   6
# 4   張鈞蓮  13  15  15   6  15
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生   9  11  10   8  15
# 96  曾桂甫  12   6   8  14  15
# 97  林欣怡  15  15  13  13  13
# 98  林佳霖  15  15  10  15  14
# 99  胡筱芸   6  12  15   8  10
#
# [100 rows x 6 columns]

# %%
df_x = pd.concat([df_names,df_grades],axis=1)

# %%
df_x
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧  13   7   9   7  12
# 1   王紹尹   8   6  11   8   9
# 2   黃季坤  11  13   7  11  15
# 3   許正書  14  12  10  10   6
# 4   張鈞蓮  13  15  15   6  15
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生   9  11  10   8  15
# 96  曾桂甫  12   6   8  14  15
# 97  林欣怡  15  15  13  13  13
# 98  林佳霖  15  15  10  15  14
# 99  胡筱芸   6  12  15   8  10
#
# [100 rows x 6 columns]
